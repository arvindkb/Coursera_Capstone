# %%
import sys
# !{sys.executable} -m pip install wikipedia
# Out:
# Collecting wikipedia
#   Downloading https://files.pythonhosted.org/packages/67/35/25e68fbc99e672127cc6fbb14b8ec1ba3dfef035bf1e4c90f78f24a80b7d/wikipedia-1.4.0.tar.gz
# Requirement already satisfied: beautifulsoup4 in c:\users\dell\anaconda3\lib\site-packages (from wikipedia) (4.6.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from wikipedia) (2.21.0)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2018.11.29)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\dell\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (1.24.1)
# Building wheels for collected packages: wikipedia
#   Running setup.py bdist_wheel for wikipedia: started
#   Running setup.py bdist_wheel for wikipedia: finished with status 'done'
#   Stored in directory: C:\Users\Dell\AppData\Local\pip\Cache\wheels\87\2a\18\4e471fd96d12114d16fe4a446d00c3b38fb9efcb744bd31f4a
# Successfully built wikipedia
# Installing collected packages: wikipedia
# Successfully installed wikipedia-1.4.0

# %%
import pandas as pd
import wikipedia as wp

# %% [markdown]
# # Get the table from wiki page

# %%
PostalCodeCanadaTable = wp.page("List of postal codes of Canada: M").html().encode("UTF-8")
df_PostalCodeCanada = pd.read_html(PostalCodeCanadaTable, header = 0)[0]

# %% [markdown]
# # Drope the rows with Borough of "Not assigned"

# %%
df_assigned = df_PostalCodeCanada[df_PostalCodeCanada.Borough != 'Not assigned']
df_assigned.reset_index(drop = True, inplace = True)

# %% [markdown]
# # Merge rows with the same Postcode

# %%
df_assigned = df_assigned.groupby(['Postcode', 'Borough'], as_index=False).agg(lambda x: ', '.join(set(x)))

# %% [markdown]
# # Set 'Not assigned' Neigbourhood to be equal to Borough

# %%
na_nb_idx =df_assigned['Neighbourhood'] == 'Not assigned'
df_assigned.loc[na_nb_idx, 'Neighbourhood'] = df_assigned[na_nb_idx].Borough
df_assigned[df_assigned['Postcode'] == 'M5A']
# Out:
#    Postcode           Borough Neighbourhood
# 53      M5A  Downtown Toronto  Harbourfront

# %% [markdown]
# # Show the shape of the data frame

# %%
df_assigned.shape
# Out:
# (103, 3)

# %% [markdown]
# # Show the dataframe data

# %%
df_assigned
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# 29       M3J        North York
# ..       ...               ...
# 73       M6C              York
# 74       M6E              York
# 75       M6G  Downtown Toronto
# 76       M6H      West Toronto
# 77       M6J      West Toronto
# 78       M6K      West Toronto
# 79       M6L        North York
# 80       M6M              York
# 81       M6N              York
# 82       M6P      West Toronto
# 83       M6R      West Toronto
# 84       M6S      West Toronto
# 85       M7A  Downtown Toronto
# 86       M7R       Mississauga
# 87       M7Y      East Toronto
# 88       M8V         Etobicoke
# 89       M8W         Etobicoke
# 90       M8X         Etobicoke
# 91       M8Y         Etobicoke
# 92       M8Z         Etobicoke
# 93       M9A      Queen's Park
# 94       M9B         Etobicoke
# 95       M9C         Etobicoke
# 96       M9L        North York
# 97       M9M        North York
# 98       M9N              York
# 99       M9P         Etobicoke
# 100      M9R         Etobicoke
# 101      M9V         Etobicoke
# 102      M9W         Etobicoke
#
#                                          Neighbourhood
# 0                                       Malvern, Rouge
# 1               Highland Creek, Port Union, Rouge Hill
# 2                    Guildwood, West Hill, Morningside
# 3                                               Woburn
# 4                                            Cedarbrae
# 5                                  Scarborough Village
# 6          Kennedy Park, Ionview, East Birchmount Park
# 7                      Oakridge, Clairlea, Golden Mile
# 8      Cliffcrest, Cliffside, Scarborough Village West
# 9                          Cliffside West, Birch Cliff
# 10   Wexford Heights, Dorset Park, Scarborough Town...
# 11                                   Maryvale, Wexford
# 12                                           Agincourt
# 13             Tam O'Shanter, Sullivan, Clarks Corners
# 14   L'Amoreaux East, Agincourt North, Milliken, St...
# 15                                     L'Amoreaux West
# 16                                         Upper Rouge
# 17                                   Hillcrest Village
# 18                        Oriole, Fairview, Henry Farm
# 19                                     Bayview Village
# 20                            York Mills, Silver Hills
# 21                             Newtonbrook, Willowdale
# 22                                    Willowdale South
# 23                                     York Mills West
# 24                                     Willowdale West
# 25                                           Parkwoods
# 26                                     Don Mills North
# 27                    Don Mills South, Flemingdon Park
# 28     Downsview North, Wilson Heights, Bathurst Manor
# 29                     York University, Northwood Park
# ..                                                 ...
# 73                                  Humewood-Cedarvale
# 74                                 Caledonia-Fairbanks
# 75                                            Christie
# 76                        Dufferin, Dovercourt Village
# 77                            Trinity, Little Portugal
# 78        Parkdale Village, Exhibition Place, Brockton
# 79                  Upwood Park, North Park, Downsview
# 80      Keelesdale, Silverthorn, Mount Dennis, Del Ray
# 81                       The Junction North, Runnymede
# 82                       The Junction South, High Park
# 83                              Roncesvalles, Parkdale
# 84                                  Swansea, Runnymede
# 85                                        Queen's Park
# 86               Canada Post Gateway Processing Centre
# 87   Business Reply Mail Processing Centre 969 Eastern
# 88        Humber Bay Shores, Mimico South, New Toronto
# 89                              Alderwood, Long Branch
# 90       The Kingsway, Old Mill North, Montgomery Road
# 91   Sunnylea, The Queensway East, Kingsway Park So...
# 92   The Queensway West, Royal York South West, Kin...
# 93                                        Queen's Park
# 94   Princess Gardens, Islington, Martin Grove, Wes...
# 95   Bloordale Gardens, Eringate, Old Burnhamthorpe...
# 96                                       Humber Summit
# 97                                    Emery, Humberlea
# 98                                              Weston
# 99                                           Westmount
# 100  Martin Grove Gardens, Kingsview Village, Richv...
# 101  South Steeles, Albion Gardens, Jamestown, Humb...
# 102                                          Northwest
#
# [103 rows x 3 columns]
